# %%
df <- read.csv("modified_dataset.csv")

# %%
colnames(df)
head(df)
# Out:
#  [1] "X"                           "App"
#  [3] "Category"                    "Rating"
#  [5] "Reviews"                     "Size"
#  [7] "Installs"                    "Type"
#  [9] "Price"                       "Content.Rating"
# [11] "Genres"                      "Last.Updated"
# [13] "Current.Ver"                 "Android.Ver"
# [15] "sentiment_polarity_mean"     "sentiment_subjectivity_mean"
# [17] "positive"                    "negative"
# [19] "neutral"                     "positiveRate"
# [21] "negativeRate"                "neutralRate"
#   X
# 1 Coloring book moana
# 2 Garden Coloring Book
# 3 FlipaClip - Cartoon animation
# 4 Boys Photo Editor - Six Pack & Men's Suit
# 5 Colorfit - Drawing & Coloring
# 6 Animated Photo Editor
#   App                                       Category       Rating Reviews Size
# 1 Coloring book moana                       ART_AND_DESIGN 3.9       967  14M
# 2 Garden Coloring Book                      ART_AND_DESIGN 4.4     13791  33M
# ...

# %%
cor.test(df$Reviews, df$Rating)
plot(df$Reviews, df$Rating)
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$Reviews and df$Rating
# t = 2.1981, df = 814, p-value = 0.02822
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.008228393 0.144684003
# sample estimates:
#        cor
# 0.07681589
# plot without title

# %%
plot(df$Size, df$Rating)
# Out:
# plot without title

# %%
plot(df$Category, df$Rating)
# Out:
# plot without title

# %%
plot(df$Installs, df$Rating)
# Out:
# plot without title

# %%
plot(df$Type, df$Rating)
# Out:
# plot without title

# %%
plot(df$Price, df$Rating)
# Out:
# plot without title

# %%
plot(df$Content.Rating, df$Rating)
# Out:
# plot without title

# %%
plot(df$Genres, df$Rating)
# Out:
# plot without title

# %%
plot(df$Last.Updated, df$Rating)
# Out:
# plot without title

# %%
plot(df$Current.Ver, df$Rating)
# Out:
# plot without title

# %%
plot(df$Android.Ver, df$Rating)
# Out:
# plot without title

# %%
cor.test(df$sentiment_polarity_mean, df$Rating)
plot(df$sentiment_polarity_mean, df$Rating)
abline(lm(df$Rating~df$sentiment_polarity_mean), col="red")
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$sentiment_polarity_mean and df$Rating
# t = 7.8127, df = 814, p-value = 1.726e-14
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.199090 0.326819
# sample estimates:
#       cor
# 0.2641121
# plot without title

# %%
cor.test(df$sentiment_subjectivity_mean, df$Rating)
plot(df$sentiment_subjectivity_mean, df$Rating)
abline(lm(df$Rating~df$sentiment_subjectivity_mean), col="red")
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$sentiment_subjectivity_mean and df$Rating
# t = 6.2986, df = 814, p-value = 4.91e-10
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.1491521 0.2800635
# sample estimates:
#       cor
# 0.2155762
# plot without title

# %%
cor.test(df$positiveRate, df$Rating)
plot(df$positiveRate, df$Rating)
abline(lm(df$Rating~df$positiveRate), col="red")
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$positiveRate and df$Rating
# t = 9.5269, df = 814, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.2536087 0.3771593
# sample estimates:
#       cor
# 0.3167268
# plot without title

# %%
cor.test(df$negativeRate, df$Rating)
plot(df$negativeRate, df$Rating)
abline(lm(df$Rating~df$negativeRate), col="red")
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$negativeRate and df$Rating
# t = -5.4417, df = 814, p-value = 6.985e-08
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2527365 -0.1202710
# sample estimates:
#        cor
# -0.1873554
# plot without title

# %%
cor.test(df$neutralRate, df$Rating)
plot(df$neutralRate, df$Rating)
abline(lm(df$Rating~df$neutralRate), col="red")
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$neutralRate and df$Rating
# t = -6.1203, df = 814, p-value = 1.451e-09
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2744251 -0.1431747
# sample estimates:
#        cor
# -0.2097445
# plot without title

# %%
df2 <- cbind(df$Rating, df$neutralRate, df$negativeRate, df$sentiment_polarity_mean)

# %%
library(psych)
pairs.panels(df2, pch=21,main="Correlation", ci=T)
# Out:
# plot without title

# %%
pairs(df2)
# Out:
# plot without title

# %%
cor.test(df$Rating, df$neutralRate)
cor.test(df$Rating, df$negativeRate)
cor.test(df$Rating, df$sentiment_polarity_mean)
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$Rating and df$neutralRate
# t = -6.1203, df = 814, p-value = 1.451e-09
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2744251 -0.1431747
# sample estimates:
#        cor
# -0.2097445
# 	Pearson's product-moment correlation
#
# data:  df$Rating and df$negativeRate
# t = -5.4417, df = 814, p-value = 6.985e-08
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.2527365 -0.1202710
# sample estimates:
#        cor
# -0.1873554
# 	Pearson's product-moment correlation
#
# data:  df$Rating and df$sentiment_polarity_mean
# t = 7.8127, df = 814, p-value = 1.726e-14
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.199090 0.326819
# sample estimates:
#       cor
# 0.2641121
